# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0,
    streaming=True
)

# %%
for chunk in llm.stream("Explain LangChain in one sentence."):
    print(chunk.content, end="")
# Out:
# LangChain is a framework designed to facilitate the development of applications powered by large language models (LLMs), enabling seamless integration with various data sources and tools), enabling seamless integration with various data sources and tools to build complex, context-aware applications. to build complex, context-aware applications.
